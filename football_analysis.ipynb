# %%
import pandas as pd
from string import ascii_uppercase as alphabet
import pickle

# %% [markdown]
# # 1. Extracting tables from groups A-H

# %%
# URL of the Wikipedia page containing the tables
url = "https://web.archive.org/web/20221115040351/https://en.wikipedia.org/wiki/2022_FIFA_World_Cup"

# Reading all tables from the specified URL
all_tables = pd.read_html(url)

# %%
all_tables
# Out:
# [      0     1     2
#  0   Oct   NOV   Dec
#  1   NaN    15   NaN
#  2  2021  2022  2023,
#    2022 كأس العالم لكرة القدم Kaʾs al-ʿālam li-kurat al-qadam 2022 Qatar 2022 2022 قطر  \
#  0                                         Now is All
#  1                                 Tournament details
#  2                                       Host country
#  3                                              Dates
#  4                                              Teams
#  5                                           Venue(s)
#  6                                      ← 2018 2026 →
#
#    2022 كأس العالم لكرة القدم Kaʾs al-ʿālam li-kurat al-qadam 2022 Qatar 2022 2022 قطر.1
#  0                                         Now is All
#  1                                 Tournament details
#  2                                              Qatar
#  3                          20 November – 18 December
#  4                         32 (from 5 confederations)
#  5                               8 (in 5 host cities)
#  6                                      ← 2018 2026 →                                     ,
#           Bidders   Votes
#           Bidders Round 1     Round 2     Round 3     Round 4
#  0          Qatar      11          10          11          14
#  1  United States       3           5           6           8
#  2    South Korea       4           5           5  Eliminated
#  3          Japan       3           2  Eliminated  Eliminated
#  4      Australia       1  Eliminated  Eliminated  Eliminated,
#                                                     0  \
#  0  AFC (6)  Australia (38)  Iran (20)  Japan (24)...
#
#                                                     1  \
#  0  CONCACAF (4)  Canada (41)  Costa Rica (31)  Me...
#
#                                                     2  \
#  0  UEFA (13)  Belgium (2)  Croatia (12)  Denmark ...
#
#                                                     3
#  0  Team qualified Team failed to qualify Team wit...  ,
#                                                 Pot 1  \
#  0  Qatar (51) (hosts)  Brazil (1)  Belgium (2)  F...
#
#                                                 Pot 2  \
#  0  Mexico (9)  Netherlands (10)  Denmark (11)  Ge...
#
#                                                 Pot 3  \
#  0  Senegal (20)  Iran (21)  Japan (23)  Morocco (...
#
#                                                 Pot 4
#  0  Cameroon (37)  Canada (38)  Ecuador (46)  Saud...  ,
#                                                       0  \
#  0    Referees Confederation Referee AFC Abdulrahman...
#  1                                             Referees
#  2                                        Confederation
#  3                                                  AFC
#  4                                                  AFC
#  ..                                                 ...
#  131                                               UEFA
#  132                                               UEFA
#  133                                               UEFA
#  134                                               UEFA
#  135                                               UEFA
#
#                                                       1  \
#  0    Assistant referees Confederation Assistant ref...
#  1                                             Referees
#  2                                              Referee
#  3                        Abdulrahman Al-Jassim (Qatar)
#  4                              Chris Beath (Australia)
#  ..                                                 ...
#  131                        Tomasz Kwiatkowski (Poland)
#  132                      Juan Martínez Munuera (Spain)
#  133                             Benoît Millot (France)
#  134                               Paolo Valeri (Italy)
#  135                       Pol van Boekel (Netherlands)
#
#                                                       2
#  0    Video assistant referees Confederation Video a...
#  1                                                  NaN
#  2                                                  NaN
#  3                                                  NaN
#  4                                                  NaN
#  ..                                                 ...
#  131                                                NaN
#  132                                                NaN
#  133                                                NaN
#  134                                                NaN
#  135                                                NaN
#
#  [136 rows x 3 columns],
#          Referees
#     Confederation                                            Referee
#  0            AFC                      Abdulrahman Al-Jassim (Qatar)
#  1            AFC                            Chris Beath (Australia)
#  2            AFC                             Alireza Faghani (Iran)
#  3            AFC                                    Ma Ning (China)
#  4            AFC  Mohammed Abdulla Hassan Mohamed (United Arab E...
#  5            AFC                          Yoshimi Yamashita (Japan)
#  6            CAF                            Bakary Gassama (Gambia)
#  7            CAF                         Mustapha Ghorbal (Algeria)
#  8            CAF                        Victor Gomes (South Africa)
#  9            CAF                         Salima Mukansanga (Rwanda)
#  10           CAF                          Maguette Ndiaye (Senegal)
#  11           CAF                             Janny Sikazwe (Zambia)
#  12      CONCACAF                          Iván Barton (El Salvador)
#  13      CONCACAF                      Ismail Elfath (United States)
#  14      CONCACAF                          Mario Escobar (Guatemala)
#  15      CONCACAF                           Said Martínez (Honduras)
#  16      CONCACAF                        César Arturo Ramos (Mexico)
#  17      CONMEBOL                             Raphael Claus (Brazil)
#  18      CONMEBOL                           Andrés Matonte (Uruguay)
#  19      CONMEBOL                                Kevin Ortega (Peru)
#  20      CONMEBOL                     Fernando Rapallini (Argentina)
#  21      CONMEBOL                            Wilton Sampaio (Brazil)
#  22      CONMEBOL                          Facundo Tello (Argentina)
#  23      CONMEBOL                       Jesús Valenzuela (Venezuela)
#  24           OFC                       Matthew Conger (New Zealand)
#  25          UEFA                        Stéphanie Frappart (France)
#  26          UEFA                            István Kovács (Romania)
#  27          UEFA                       Danny Makkelie (Netherlands)
#  28          UEFA                          Szymon Marciniak (Poland)
#  29          UEFA                        Antonio Mateu Lahoz (Spain)
#  30          UEFA                           Michael Oliver (England)
#  31          UEFA                             Daniele Orsato (Italy)
#  32          UEFA                           Daniel Siebert (Germany)
#  33          UEFA                           Anthony Taylor (England)
#  34          UEFA                            Clément Turpin (France)
#  35          UEFA                           Slavko Vinčić (Slovenia),
#     Assistant referees
#          Confederation                          Assistant referee
#  0                 AFC              Mohammadreza Abolfazli (Iran)
#  1                 AFC                     Taleb Al-Marri (Qatar)
#  2                 AFC  Mohamed Al-Hammadi (United Arab Emirates)
#  3                 AFC      Hasan Al-Mahri (United Arab Emirates)
#  4                 AFC                    Saud Al-Maqaleh (Qatar)
#  ..                ...                                        ...
#  64               UEFA                 Vasile Marinescu (Romania)
#  65               UEFA                        Adam Nunn (England)
#  66               UEFA                       Jan Seidel (Germany)
#  67               UEFA                  Paweł Sokolnicki (Poland)
#  68               UEFA             Hessel Steegstra (Netherlands)
#
#  [69 rows x 2 columns],
#     Video assistant referees
#                Confederation                Video assistant referee
#  0                       AFC               Abdulla Al-Marri (Qatar)
#  1                       AFC              Muhammad Taqi (Singapore)
#  2                       AFC                Shaun Evans (Australia)
#  3                       CAF               Rédouane Jiyed (Morocco)
#  4                       CAF                  Adil Zourak (Morocco)
#  5                  CONCACAF                  Drew Fischer (Canada)
#  6                  CONCACAF             Fernando Guerrero (Mexico)
#  7                  CONCACAF     Armando Villarreal (United States)
#  8                  CONMEBOL                 Julio Bascuñán (Chile)
#  9                  CONMEBOL               Nicolás Gallo (Colombia)
#  10                 CONMEBOL              Leodán González (Uruguay)
#  11                 CONMEBOL                  Juan Soto (Venezuela)
#  12                 CONMEBOL             Mauro Vigliano (Argentina)
#  13                     UEFA                Jérôme Brisard (France)
#  14                     UEFA              Bastian Dankert (Germany)
#  15                     UEFA   Ricardo de Burgos Bengoetxea (Spain)
#  16                     UEFA                  Marco Fritz (Germany)
#  17                     UEFA  Alejandro Hernández Hernández (Spain)
#  18                     UEFA            Massimiliano Irrati (Italy)
#  19                     UEFA            Tomasz Kwiatkowski (Poland)
#  20                     UEFA          Juan Martínez Munuera (Spain)
#  21                     UEFA                 Benoît Millot (France)
#  22                     UEFA                   Paolo Valeri (Italy)
#  23                     UEFA           Pol van Boekel (Netherlands),
#                                                Lusail  \
#  0                              Lusail Iconic Stadium
#  1                                   Capacity: 80,000
#  2                                                NaN
#  3  Host cities in QatarLusailDohaAl KhorAl Wakrah...
#  4                                          Al Rayyan
#  5                      Khalifa International Stadium
#  6                               Capacity: 45,416[73]
#  7                                                NaN
#
#                                               Al Khor  \
#  0                                    Al Bayt Stadium
#  1                               Capacity: 60,000[70]
#  2                                                NaN
#  3  Host cities in QatarLusailDohaAl KhorAl Wakrah...
#  4                                          Al Rayyan
#  5                             Education City Stadium
#  6                               Capacity: 45,350[74]
#  7                                                NaN
#
#                                                  Doha  \
#  0                                        Stadium 974
#  1                               Capacity: 40,000[71]
#  2                                                NaN
#  3  Stadiums in Doha areaEducation974KhalifaAl Thu...
#  4                                          Al Rayyan
#  5                           Ahmad bin Ali Stadium[e]
#  6                               Capacity: 44,740[75]
#  7                                                NaN
#
#                                                Doha.1
#  0                                 Al Thumama Stadium
#  1                               Capacity: 40,000[72]
#  2                                                NaN
#  3  Stadiums in Doha areaEducation974KhalifaAl Thu...
#  4                                          Al Wakrah
#  5                                  Al Janoub Stadium
#  6                               Capacity: 40,000[76]
#  7                                                NaN  ,
#              Teams                                             Hotels  \
#  0       Argentina                          Qatar University Hostel 1
#  1       Australia           New Aspire Academy Athlete Accommodation
#  2         Belgium               Hilton Salwa Beach Resort and Villas
#  3          Brazil                      The Westin Doha Hotel and Spa
#  4        Cameroon            Banyan Tree Doha At La Cigale Mushaireb
#  5          Canada                        Century Marina Hotel Lusail
#  6      Costa Rica                                 dusitD2 Salwa Doha
#  7         Croatia                                        Hilton Doha
#  8         Denmark                           Retaj Salwa Resort & SPA
#  9         Ecuador                            Hyatt Regency Oryx Doha
#  10        England                Souq Al Wakra Hotel Qatar by Tivoli
#  11         France  Al Messila – A Luxury Collection Resort & Spa,...
#  12        Germany                              Zulal Wellness Resort
#  13          Ghana                DoubleTree by Hilton Doha - Al Sadd
#  14           Iran    Al Rayyan Hotel Doha Curio Collection by Hilton
#  15          Japan                            Radisson Blu Hotel Doha
#  16         Mexico                          Simaisma, A Murwab Resort
#  17        Morocco                              Wyndham Doha West Bay
#  18    Netherlands                                 The St. Regis Doha
#  19         Poland                                 Ezdan Palace Hotel
#  20       Portugal              Al Samriya Autograph Collection Hotel
#  21          Qatar                         Al Aziziyah Boutique Hotel
#  22   Saudi Arabia                     Sealine Beach, a Murwab Resort
#  23        Senegal                        Duhail Handball Sports Hall
#  24         Serbia                              Rixos Gulf Hotel Doha
#  25    South Korea                       Le Méridien City Center Doha
#  26          Spain                          Qatar University Hostel 2
#  27    Switzerland                            Le Royal Méridien, Doha
#  28        Tunisia                  Wyndham Grand Doha West Bay Beach
#  29  United States            Marsa Malaz Kempinski, The Pearl – Doha
#  30        Uruguay                              Pullman Doha West Bay
#  31          Wales                      Delta Hotels City Center Doha
#
#                              Training Sites
#  0         Qatar University Training Site 3
#  1        Aspire Zone Training Facilities 5
#  2                      Salwa Training Site
#  3                      Al Arabi SC Stadium
#  4                    Al Sailiya SC Stadium
#  5         Umm Salal SC Training Facilities
#  6                       Al Ahli SC Stadium
#  7                 Al Ersal Training Site 3
#  8                          Al Sailiya SC 2
#  9         Mesaimeer SC Training Facilities
#  10                    Al Wakrah SC Stadium
#  11                      Al Sadd SC Stadium
#  12                       Al Shamal Stadium
#  13       Aspire Zone Training Facilities 1
#  14      Al Rayyan SC Training Facilities 1
#  15    Al Sadd SC New Training Facilities 1
#  16                      Al Khor SC Stadium
#  17                    Al Duhail SC Stadium
#  18        Qatar University Training Site 6
#  19   Al Kharaitiyat SC Training Facilities
#  20     Al Shahaniya SC Training Facilities
#  21       Aspire Zone Training Facilities 3
#  22                   Sealine Training Site
#  23                          Al Duhail SC 2
#  24         Al Arabi SC Training Facilities
#  25                 Al Egla Training Site 5
#  26        Qatar University Training Site 1
#  27  University of Doha Training Facilities
#  28                Al Egla Training Sites 3
#  29                   Al Gharafa SC Stadium
#  30                Al Ersal Training Site 1
#  31    Al Sadd SC New Training Facilities 2  ,
#                  Tie-breaking criteria for group play
#  0  The ranking of teams in the group stage is det...,
#     Pos      Teamvte  Pld  W  D  L  GF  GA  GD  Pts              Qualification
#  0    1    Qatar (H)    0  0  0  0   0   0   0    0  Advance to knockout stage
#  1    2      Ecuador    0  0  0  0   0   0   0    0  Advance to knockout stage
#  2    3      Senegal    0  0  0  0   0   0   0    0                        NaN
#  3    4  Netherlands    0  0  0  0   0   0   0    0                        NaN,
#     Qatar Match 1  Ecuador
#  0    NaN  Report      NaN,
#     Senegal Match 2  Netherlands
#  0      NaN  Report          NaN,
#     Qatar Match 18  Senegal
#  0    NaN   Report      NaN,
#     Netherlands Match 19  Ecuador
#  0          NaN   Report      NaN,
#     Ecuador Match 35  Senegal
#  0      NaN   Report      NaN,
#     Netherlands Match 36  Qatar
#  0          NaN   Report    NaN,
#     Pos        Teamvte  Pld  W  D  L  GF  GA  GD  Pts  \
#  0    1        England    0  0  0  0   0   0   0    0
#  1    2           Iran    0  0  0  0   0   0   0    0
#  2    3  United States    0  0  0  0   0   0   0    0
#  3    4          Wales    0  0  0  0   0   0   0    0
#
#                 Qualification
#  0  Advance to knockout stage
#  1  Advance to knockout stage
#  2                        NaN
#  3                        NaN  ,
#     England Match 3  Iran
#  0      NaN  Report   NaN,
#     United States Match 4  Wales
#  0            NaN  Report    NaN,
#     Wales Match 17  Iran
#  0    NaN   Report   NaN,
#     England Match 20  United States
#  0      NaN   Report            NaN,
#     Wales Match 33  England
#  0    NaN   Report      NaN,
#     Iran Match 34  United States
#  0   NaN   Report            NaN,
#     Pos       Teamvte  Pld  W  D  L  GF  GA  GD  Pts              Qualification
#  0    1     Argentina    0  0  0  0   0   0   0    0  Advance to knockout stage
#  1    2  Saudi Arabia    0  0  0  0   0   0   0    0  Advance to knockout stage
#  2    3        Mexico    0  0  0  0   0   0   0    0                        NaN
#  3    4        Poland    0  0  0  0   0   0   0    0                        NaN,
#     Argentina Match 8  Saudi Arabia
#  0        NaN  Report           NaN,
#     Mexico Match 7  Poland
#  0     NaN  Report     NaN,
#     Poland Match 22  Saudi Arabia
#  0     NaN   Report           NaN,
#     Argentina Match 24  Mexico
#  0        NaN   Report     NaN,
#     Poland Match 39  Argentina
#  0     NaN   Report        NaN,
#     Saudi Arabia Match 40  Mexico
#  0           NaN   Report     NaN,
#     Pos    Teamvte  Pld  W  D  L  GF  GA  GD  Pts              Qualification
#  0    1     France    0  0  0  0   0   0   0    0  Advance to knockout stage
#  1    2  Australia    0  0  0  0   0   0   0    0  Advance to knockout stage
#  2    3    Denmark    0  0  0  0   0   0   0    0                        NaN
#  3    4    Tunisia    0  0  0  0   0   0   0    0                        NaN,
#     Denmark Match 6  Tunisia
#  0      NaN  Report      NaN,
#     France Match 5  Australia
#  0     NaN  Report        NaN,
#     Tunisia Match 21  Australia
#  0      NaN   Report        NaN,
#     France Match 23  Denmark
#  0     NaN   Report      NaN,
#     Australia Match 37  Denmark
#  0        NaN   Report      NaN,
#     Tunisia Match 38  France
#  0      NaN   Report     NaN,
#     Pos     Teamvte  Pld  W  D  L  GF  GA  GD  Pts              Qualification
#  0    1       Spain    0  0  0  0   0   0   0    0  Advance to knockout stage
#  1    2  Costa Rica    0  0  0  0   0   0   0    0  Advance to knockout stage
#  2    3     Germany    0  0  0  0   0   0   0    0                        NaN
#  3    4       Japan    0  0  0  0   0   0   0    0                        NaN,
#     Germany Match 11  Japan
#  0      NaN   Report    NaN,
#     Spain Match 10  Costa Rica
#  0    NaN   Report         NaN,
#     Japan Match 25  Costa Rica
#  0    NaN   Report         NaN,
#     Spain Match 28  Germany
#  0    NaN   Report      NaN,
#     Japan Match 43  Spain
#  0    NaN   Report    NaN,
#     Costa Rica Match 44  Germany
#  0         NaN   Report      NaN,
#     Pos  Teamvte  Pld  W  D  L  GF  GA  GD  Pts              Qualification
#  0    1  Belgium    0  0  0  0   0   0   0    0  Advance to knockout stage
#  1    2   Canada    0  0  0  0   0   0   0    0  Advance to knockout stage
#  2    3  Morocco    0  0  0  0   0   0   0    0                        NaN
#  3    4  Croatia    0  0  0  0   0   0   0    0                        NaN,
#     Morocco Match 12  Croatia
#  0      NaN   Report      NaN,
#     Belgium Match 9  Canada
#  0      NaN  Report     NaN,
#     Belgium Match 26  Morocco
#  0      NaN   Report      NaN,
#     Croatia Match 27  Canada
#  0      NaN   Report     NaN,
#     Croatia Match 41  Belgium
#  0      NaN   Report      NaN,
#     Canada Match 42  Morocco
#  0     NaN   Report      NaN,
#     Pos      Teamvte  Pld  W  D  L  GF  GA  GD  Pts              Qualification
#  0    1       Brazil    0  0  0  0   0   0   0    0  Advance to knockout stage
#  1    2       Serbia    0  0  0  0   0   0   0    0  Advance to knockout stage
#  2    3  Switzerland    0  0  0  0   0   0   0    0                        NaN
#  3    4     Cameroon    0  0  0  0   0   0   0    0                        NaN,
#     Switzerland Match 13  Cameroon
#  0          NaN   Report       NaN,
#     Brazil Match 16  Serbia
#  0     NaN   Report     NaN,
#     Cameroon Match 29  Serbia
#  0       NaN   Report     NaN,
#     Brazil Match 31  Switzerland
#  0     NaN   Report          NaN,
#     Serbia Match 47  Switzerland
#  0     NaN   Report          NaN,
#     Cameroon Match 48  Brazil
#  0       NaN   Report     NaN,
#     Pos      Teamvte  Pld  W  D  L  GF  GA  GD  Pts              Qualification
#  0    1     Portugal    0  0  0  0   0   0   0    0  Advance to knockout stage
#  1    2        Ghana    0  0  0  0   0   0   0    0  Advance to knockout stage
#  2    3      Uruguay    0  0  0  0   0   0   0    0                        NaN
#  3    4  South Korea    0  0  0  0   0   0   0    0                        NaN,
#     Uruguay Match 14  South Korea
#  0      NaN   Report          NaN,
#     Portugal Match 15  Ghana
#  0       NaN   Report    NaN,
#     South Korea Match 30  Ghana
#  0          NaN   Report    NaN,
#     Portugal Match 32  Uruguay
#  0       NaN   Report      NaN,
#     Ghana Match 45  Uruguay
#  0    NaN   Report      NaN,
#     South Korea Match 46  Portugal
#  0          NaN   Report       NaN,
#      0                                       1   \
#  0  NaN                             Round of 16
#  1  NaN                                     NaN
#  2  NaN        3 December – Al Rayyan (Khalifa)
#  3  NaN        3 December – Al Rayyan (Khalifa)
#  4  NaN                         Winners Group A
#  5  NaN                         Winners Group A
#  6  NaN                      Runners-up Group B
#  7  NaN                      Runners-up Group B
#  8  NaN  3 December – Al Rayyan (Ahmad bin Ali)
#  9  NaN  3 December – Al Rayyan (Ahmad bin Ali)
#  10 NaN                         Winners Group C
#  11 NaN                         Winners Group C
#  12 NaN                      Runners-up Group D
#  13 NaN                      Runners-up Group D
#  14 NaN                  5 December – Al Wakrah
#  15 NaN                  5 December – Al Wakrah
#  16 NaN                         Winners Group E
#  17 NaN                         Winners Group E
#  18 NaN                      Runners-up Group F
#  19 NaN                      Runners-up Group F
#  20 NaN                 5 December – Doha (974)
#  21 NaN                 5 December – Doha (974)
#  22 NaN                         Winners Group G
#  23 NaN                         Winners Group G
#  24 NaN                      Runners-up Group H
#  25 NaN                      Runners-up Group H
#  26 NaN                    4 December – Al Khor
#  27 NaN                    4 December – Al Khor
#  28 NaN                         Winners Group B
#  29 NaN                         Winners Group B
#  30 NaN                      Runners-up Group A
#  31 NaN                      Runners-up Group A
#  32 NaN          4 December – Doha (Al Thumama)
#  33 NaN          4 December – Doha (Al Thumama)
#  34 NaN                         Winners Group D
#  35 NaN                         Winners Group D
#  36 NaN                      Runners-up Group C
#  37 NaN                      Runners-up Group C
#  38 NaN      6 December – Al Rayyan (Education)
#  39 NaN      6 December – Al Rayyan (Education)
#  40 NaN                         Winners Group F
#  41 NaN                         Winners Group F
#  42 NaN                      Runners-up Group E
#  43 NaN                      Runners-up Group E
#  44 NaN                     6 December – Lusail
#  45 NaN                     6 December – Lusail
#  46 NaN                         Winners Group H
#  47 NaN                         Winners Group H
#  48 NaN                      Runners-up Group G
#  49 NaN                      Runners-up Group G
#  50 NaN                                     NaN
#  51 NaN                                     NaN
#  52 NaN                                     NaN
#  53 NaN                                     NaN
#  54 NaN                                     NaN
#  55 NaN                                     NaN
#  56 NaN                                     NaN
#  57 NaN                                     NaN
#  58 NaN                                     NaN
#
#                                          2   3   4   \
#  0                              Round of 16 NaN NaN
#  1                                      NaN NaN NaN
#  2         3 December – Al Rayyan (Khalifa) NaN NaN
#  3         3 December – Al Rayyan (Khalifa) NaN NaN
#  4                                      NaN NaN NaN
#  5                                      NaN NaN NaN
#  6                                      NaN NaN NaN
#  7                                      NaN NaN NaN
#  8   3 December – Al Rayyan (Ahmad bin Ali) NaN NaN
#  9   3 December – Al Rayyan (Ahmad bin Ali) NaN NaN
#  10                                     NaN NaN NaN
#  11                                     NaN NaN NaN
#  12                                     NaN NaN NaN
#  13                                     NaN NaN NaN
#  14                  5 December – Al Wakrah NaN NaN
#  15                  5 December – Al Wakrah NaN NaN
#  16                                     NaN NaN NaN
#  17                                     NaN NaN NaN
#  18                                     NaN NaN NaN
#  19                                     NaN NaN NaN
#  20                 5 December – Doha (974) NaN NaN
#  21                 5 December – Doha (974) NaN NaN
#  22                                     NaN NaN NaN
#  23                                     NaN NaN NaN
#  24                                     NaN NaN NaN
#  25                                     NaN NaN NaN
#  26                    4 December – Al Khor NaN NaN
#  27                    4 December – Al Khor NaN NaN
#  28                                     NaN NaN NaN
#  29                                     NaN NaN NaN
#  30                                     NaN NaN NaN
#  31                                     NaN NaN NaN
#  32          4 December – Doha (Al Thumama) NaN NaN
#  33          4 December – Doha (Al Thumama) NaN NaN
#  34                                     NaN NaN NaN
#  35                                     NaN NaN NaN
#  36                                     NaN NaN NaN
#  37                                     NaN NaN NaN
#  38      6 December – Al Rayyan (Education) NaN NaN
#  39      6 December – Al Rayyan (Education) NaN NaN
#  40                                     NaN NaN NaN
#  41                                     NaN NaN NaN
#  42                                     NaN NaN NaN
#  43                                     NaN NaN NaN
#  44                     6 December – Lusail NaN NaN
#  45                     6 December – Lusail NaN NaN
#  46                                     NaN NaN NaN
#  47                                     NaN NaN NaN
#  48                                     NaN NaN NaN
#  49                                     NaN NaN NaN
#  50                                     NaN NaN NaN
#  51                                     NaN NaN NaN
#  52                                     NaN NaN NaN
#  53                                     NaN NaN NaN
#  54                                     NaN NaN NaN
#  55                                     NaN NaN NaN
#  56                                     NaN NaN NaN
#  57                                     NaN NaN NaN
#  58                                     NaN NaN NaN
#
#                                      5                                   6   \
#  0                       Quarter-finals                      Quarter-finals
#  1                                  NaN                                 NaN
#  2                                  NaN                                 NaN
#  3                                  NaN                                 NaN
#  4                                  NaN                                 NaN
#  5                  9 December – Lusail                 9 December – Lusail
#  6                  9 December – Lusail                 9 December – Lusail
#  7                     Winners Match 49                                 NaN
#  8                     Winners Match 49                                 NaN
#  9                     Winners Match 50                                 NaN
#  10                    Winners Match 50                                 NaN
#  11                                 NaN                                 NaN
#  12                                 NaN                                 NaN
#  13                                 NaN                                 NaN
#  14                                 NaN                                 NaN
#  15                                 NaN                                 NaN
#  16                                 NaN                                 NaN
#  17  9 December – Al Rayyan (Education)  9 December – Al Rayyan (Education)
#  18  9 December – Al Rayyan (Education)  9 December – Al Rayyan (Education)
#  19                    Winners Match 53                                 NaN
#  20                    Winners Match 53                                 NaN
#  21                    Winners Match 54                                 NaN
#  22                    Winners Match 54                                 NaN
#  23                                 NaN                                 NaN
#  24                                 NaN                                 NaN
#  25                                 NaN                                 NaN
#  26                                 NaN                                 NaN
#  27                                 NaN                                 NaN
#  28                                 NaN                                 NaN
#  29               10 December – Al Khor               10 December – Al Khor
#  30               10 December – Al Khor               10 December – Al Khor
#  31                    Winners Match 51                                 NaN
#  32                    Winners Match 51                                 NaN
#  33                    Winners Match 52                                 NaN
#  34                    Winners Match 52                                 NaN
#  35                                 NaN                                 NaN
#  36                                 NaN                                 NaN
#  37                                 NaN                                 NaN
#  38                                 NaN                                 NaN
#  39                                 NaN                                 NaN
#  40                                 NaN                                 NaN
#  41     10 December – Doha (Al Thumama)     10 December – Doha (Al Thumama)
#  42     10 December – Doha (Al Thumama)     10 December – Doha (Al Thumama)
#  43                    Winners Match 55                                 NaN
#  44                    Winners Match 55                                 NaN
#  45                    Winners Match 56                                 NaN
#  46                    Winners Match 56                                 NaN
#  47                                 NaN                                 NaN
#  48                                 NaN                                 NaN
#  49                                 NaN                                 NaN
#  50                                 NaN                                 NaN
#  51                                 NaN                                 NaN
#  52                                 NaN                                 NaN
#  53                                 NaN                                 NaN
#  54                                 NaN                                 NaN
#  55                                 NaN                                 NaN
#  56                                 NaN                                 NaN
#  57                                 NaN                                 NaN
#  58                                 NaN                                 NaN
#
#      7   8                      9                      10  11  12  \
#  0  NaN NaN            Semi-finals            Semi-finals NaN NaN
#  1  NaN NaN                    NaN                    NaN NaN NaN
#  2  NaN NaN                    NaN                    NaN NaN NaN
#  3  NaN NaN                    NaN                    NaN NaN NaN
#  4  NaN NaN                    NaN                    NaN NaN NaN
#  5  NaN NaN                    NaN                    NaN NaN NaN
#  6  NaN NaN                    NaN                    NaN NaN NaN
#  7  NaN NaN                    NaN                    NaN NaN NaN
#  8  NaN NaN                    NaN                    NaN NaN NaN
#  9  NaN NaN                    NaN                    NaN NaN NaN
#  10 NaN NaN                    NaN                    NaN NaN NaN
#  11 NaN NaN   13 December – Lusail   13 December – Lusail NaN NaN
#  12 NaN NaN   13 December – Lusail   13 December – Lusail NaN NaN
#  13 NaN NaN       Winners Match 57                    NaN NaN NaN
#  14 NaN NaN       Winners Match 57                    NaN NaN NaN
#  15 NaN NaN       Winners Match 58                    NaN NaN NaN
#  16 NaN NaN       Winners Match 58                    NaN NaN NaN
#  17 NaN NaN                    NaN                    NaN NaN NaN
#  18 NaN NaN                    NaN                    NaN NaN NaN
#  19 NaN NaN                    NaN                    NaN NaN NaN
#  20 NaN NaN                    NaN                    NaN NaN NaN
#  21 NaN NaN                    NaN                    NaN NaN NaN
#  22 NaN NaN                    NaN                    NaN NaN NaN
#  23 NaN NaN                    NaN                    NaN NaN NaN
#  24 NaN NaN                    NaN                    NaN NaN NaN
#  25 NaN NaN                    NaN                    NaN NaN NaN
#  26 NaN NaN                    NaN                    NaN NaN NaN
#  27 NaN NaN                    NaN                    NaN NaN NaN
#  28 NaN NaN                    NaN                    NaN NaN NaN
#  29 NaN NaN                    NaN                    NaN NaN NaN
#  30 NaN NaN                    NaN                    NaN NaN NaN
#  31 NaN NaN                    NaN                    NaN NaN NaN
#  32 NaN NaN                    NaN                    NaN NaN NaN
#  33 NaN NaN                    NaN                    NaN NaN NaN
#  34 NaN NaN                    NaN                    NaN NaN NaN
#  35 NaN NaN  14 December – Al Khor  14 December – Al Khor NaN NaN
#  36 NaN NaN  14 December – Al Khor  14 December – Al Khor NaN NaN
#  37 NaN NaN       Winners Match 59                    NaN NaN NaN
#  38 NaN NaN       Winners Match 59                    NaN NaN NaN
#  39 NaN NaN       Winners Match 60                    NaN NaN NaN
#  40 NaN NaN       Winners Match 60                    NaN NaN NaN
#  41 NaN NaN                    NaN                    NaN NaN NaN
#  42 NaN NaN                    NaN                    NaN NaN NaN
#  43 NaN NaN                    NaN                    NaN NaN NaN
#  44 NaN NaN                    NaN                    NaN NaN NaN
#  45 NaN NaN                    NaN                    NaN NaN NaN
#  46 NaN NaN                    NaN                    NaN NaN NaN
#  47 NaN NaN                    NaN                    NaN NaN NaN
#  48 NaN NaN                    NaN                    NaN NaN NaN
#  49 NaN NaN                    NaN                    NaN NaN NaN
#  50 NaN NaN                    NaN                    NaN NaN NaN
#  51 NaN NaN                    NaN                    NaN NaN NaN
#  52 NaN NaN                    NaN                    NaN NaN NaN
#  53 NaN NaN                    NaN                    NaN NaN NaN
#  54 NaN NaN                    NaN                    NaN NaN NaN
#  55 NaN NaN                    NaN                    NaN NaN NaN
#  56 NaN NaN                    NaN                    NaN NaN NaN
#  57 NaN NaN                    NaN                    NaN NaN NaN
#  58 NaN NaN                    NaN                    NaN NaN NaN
#
#                                     13                                 14
#  0                               Final                              Final
#  1                                 NaN                                NaN
#  2                                 NaN                                NaN
#  3                                 NaN                                NaN
#  4                                 NaN                                NaN
#  5                                 NaN                                NaN
#  6                                 NaN                                NaN
#  7                                 NaN                                NaN
#  8                                 NaN                                NaN
#  9                                 NaN                                NaN
#  10                                NaN                                NaN
#  11                                NaN                                NaN
#  12                                NaN                                NaN
#  13                                NaN                                NaN
#  14                                NaN                                NaN
#  15                                NaN                                NaN
#  16                                NaN                                NaN
#  17                                NaN                                NaN
#  18                                NaN                                NaN
#  19                                NaN                                NaN
#  20                                NaN                                NaN
#  21                                NaN                                NaN
#  22                                NaN                                NaN
#  23               18 December – Lusail               18 December – Lusail
#  24               18 December – Lusail               18 December – Lusail
#  25                   Winners Match 61                                NaN
#  26                   Winners Match 61                                NaN
#  27                   Winners Match 62                                NaN
#  28                   Winners Match 62                                NaN
#  29                                NaN                                NaN
#  30                                NaN                                NaN
#  31                                NaN                                NaN
#  32                                NaN                                NaN
#  33                                NaN                                NaN
#  34                                NaN                                NaN
#  35                                NaN                                NaN
#  36                                NaN                                NaN
#  37                                NaN                                NaN
#  38                                NaN                                NaN
#  39               Third place play-off               Third place play-off
#  40               Third place play-off               Third place play-off
#  41  17 December – Al Rayyan (Khalifa)  17 December – Al Rayyan (Khalifa)
#  42  17 December – Al Rayyan (Khalifa)  17 December – Al Rayyan (Khalifa)
#  43                    Losers Match 61                                NaN
#  44                    Losers Match 61                                NaN
#  45                    Losers Match 62                                NaN
#  46                    Losers Match 62                                NaN
#  47                                NaN                                NaN
#  48                                NaN                                NaN
#  49                                NaN                                NaN
#  50                                NaN                                NaN
#  51                                NaN                                NaN
#  52                                NaN                                NaN
#  53                                NaN                                NaN
#  54                                NaN                                NaN
#  55                                NaN                                NaN
#  56                                NaN                                NaN
#  57                                NaN                                NaN
#  58                                NaN                                NaN  ,
#     Winners Group A Match 49  Runners-up Group B
#  0              NaN   Report                 NaN,
#     Winners Group C Match 50  Runners-up Group D
#  0              NaN   Report                 NaN,
#     Winners Group D Match 52  Runners-up Group C
#  0              NaN   Report                 NaN,
#     Winners Group B Match 51  Runners-up Group A
#  0              NaN   Report                 NaN,
#     Winners Group E Match 53  Runners-up Group F
#  0              NaN   Report                 NaN,
#     Winners Group G Match 54  Runners-up Group H
#  0              NaN   Report                 NaN,
#     Winners Group F Match 55  Runners-up Group E
#  0              NaN   Report                 NaN,
#     Winners Group H Match 56  Runners-up Group G
#  0              NaN   Report                 NaN,
#     Winners Match 53 Match 58  Winners Match 54
#  0               NaN   Report               NaN,
#     Winners Match 49 Match 57  Winners Match 50
#  0               NaN   Report               NaN,
#     Winners Match 55 Match 60  Winners Match 56
#  0               NaN   Report               NaN,
#     Winners Match 51 Match 59  Winners Match 52
#  0               NaN   Report               NaN,
#     Winners Match 57 Match 61  Winners Match 58
#  0               NaN   Report               NaN,
#     Winners Match 59 Match 62  Winners Match 60
#  0               NaN   Report               NaN,
#     Losers Match 61 Match 63  Losers Match 62
#  0              NaN   Report              NaN,
#     Winners Match 61 Match 64  Winners Match 62
#  0               NaN   Report               NaN,
#                              Place Amount (million USD)
#                              Place             Per team Total
#  0                       Champions                   42    42
#  1                      Runners-up                   30    30
#  2                     Third place                   27    27
#  3                    Fourth place                   25    25
#  4  5th–8th place (quarter-finals)                   17    68
#  5    9th–16th place (Round of 16)                   13   104
#  6   17th–32nd place (Group stage)                    9   144
#  7                           Total                Total   440,
#                                         FIFA partners  \
#  0  Adidas[108] Coca-Cola[109] Hyundai–Kia[110] Qa...
#
#                               FIFA World Cup sponsors  \
#  0  Anheuser-Busch InBev[115] Byju's[116][117] Cry...
#
#              African and Middle Eastern supporters  \
#  0  GWC Logistics[123] Ooredoo[124] QNB Group[125]
#
#                             North American supporters  \
#  0  Algorand[126] Frito-Lay[127] The Look Company[...
#
#           South American supporters
#  0  Claro[129] Nubank[130] UPL[131]  ,
#    vte2022 FIFA World Cup                           vte2022 FIFA World Cup.1
#  0                 Stages  Group stage Group A Group B Group C Group D Gr...
#  1    General information  Qualification Bids Broadcasting rights Controv...
#  2       Official symbols  Al Rihla (ball) "Hayya Hayya (Better Together)...,
#    vte2022 FIFA World Cup stadiums  \
#  0                            Doha
#  1                       Al Rayyan
#  2                          Others
#
#                     vte2022 FIFA World Cup stadiums.1
#  0  Al Thumama Stadium Khalifa International Stadi...
#  1       Ahmad bin Ali Stadium Education City Stadium
#  2  Al Bayt Stadium (Al Khor) Al Janoub Stadium (A...  ,
#                                      vteFIFA World Cup  \
#  0                                         Tournaments
#  1                                       Qualification
#  2                                              Finals
#  3                                              Squads
#  4                                          Final draw
#  5                                        Broadcasters
#  6                                                Bids
#  7                                          Statistics
#  8                                    Team appearances
#  9                                     Overall records
#  10                                      Miscellaneous
#  11  1 There was no qualification for the 1930 Worl...
#
#                                    vteFIFA World Cup.1
#  0   Uruguay 1930 Italy 1934 France 1938 Brazil 195...
#  1   19301 1934 1938 1950 1954 1958 1962 1966 1970 ...
#  2   1930 1934 1938 19502 1954 1958 1962 1966 1970 ...
#  3   1930 1934 1938 1950 1954 1958 1962 1966 1970 1...
#  4                  1998 2002 2006 2010 2014 2018 2022
#  5                  1998 2002 2006 2010 2014 2018 2022
#  6                        2014 2018 and 2022 2026 2030
#  7                            2002 2006 2010 2014 2018
#  8                  AFC CAF CONCACAF CONMEBOL OFC UEFA
#  9   All-time table Goalscorers top goalscorers fin...
#  10  Awards Balls Controversies Economics Fan Festi...
#  11  1 There was no qualification for the 1930 Worl...  ,
#                                 vte Football in Qatar  \
#  0                         Qatar Football Association
#  1                                     National teams
#  2                                League competitions
#  3                          Domestic cup competitions
#  4                     International cup competitions
#  5                              Rivalries and derbies
#  6                               Lists and categories
#  7  Men's clubs Men's players Expatriate footballe...
#
#                               vte Football in Qatar.1
#  0                         Qatar Football Association
#  1                       Men's U-23 U-20 U-17 Women's
#  2  Qatar Stars League Qatari Second Division Qata...
#  3  Emir of Qatar Cup Qatari Stars Cup Qatar Cup Q...
#  4  Alkass International Cup International Friends...
#  5   United Arab Emirates Saudi Arabia Bahrain Kuwait
#  6                          Clubs Expatriate managers
#  7  Men's clubs Men's players Expatriate footballe...  ,
#    vteWorld championships in 2022  \
#  0  Summer sports & indoor sports
#  1                  Winter sports
#  2              Cue & mind sports
#  3                   Motor sports
#
#                      vteWorld championships in 2022.1
#  0  American football (women) Aquatics artistic sw...
#  1  Bandy men women Curling men women mixed double...
#  2  Bridge teams Carom billiards individual team C...
#  3  Electric touring car Endurance auto racing End...  ]

# %%
all_tables[12]
# all_tables[19]
# all_tables[26]

# all_tables[61]
# Out:
#    Pos      Teamvte  Pld  W  D  L  GF  GA  GD  Pts              Qualification
# 0    1    Qatar (H)    0  0  0  0   0   0   0    0  Advance to knockout stage
# 1    2      Ecuador    0  0  0  0   0   0   0    0  Advance to knockout stage
# 2    3      Senegal    0  0  0  0   0   0   0    0                        NaN
# 3    4  Netherlands    0  0  0  0   0   0   0    0                        NaN

# %%
all_tables = pd.read_html("https://web.archive.org/web/20221115040351/https://en.wikipedia.org/wiki/2022_FIFA_World_Cup")

# Dictionary to store the extracted tables
dict_table = {}

# Looping through the tables and assigning them to dictionary keys
for letter, i in zip(alphabet, range(12, 68, 7)):
    # Extracting a table from the list of tables
    df = all_tables[i]

    # Renaming the second column to 'Team'
    df.rename(columns={df.columns[1] : 'Team'}, inplace=True)

    # Removing the 'Qualification' column
    df.pop('Qualification')

    # Assigning the DataFrame to a dictionary key
    dict_table[f'Group {letter}'] = df

# %%
dict_table['Group B']
# Out:
#    Pos           Team  Pld  W  D  L  GF  GA  GD  Pts
# 0    1        England    0  0  0  0   0   0   0    0
# 1    2           Iran    0  0  0  0   0   0   0    0
# 2    3  United States    0  0  0  0   0   0   0    0
# 3    4          Wales    0  0  0  0   0   0   0    0

# %%
# Open the file 'fifa2022_group_table' in write binary mode ('wb')
with open('fifa2022_group_table', 'wb') as output:
    # Pickle the dictionary 'dict_table' and write it to the opened file
    pickle.dump(dict_table, output)

# %% [markdown]
# # 2. Extracting football matches

# %%
from bs4 import BeautifulSoup
import requests

# List of Fifa World Cup years
years = [1930, 1934, 1938, 1950, 1954, 1958, 1962, 1966, 1970, 1974, 1978,
         1982, 1986, 1990, 1994, 1998, 2002, 2006, 2010, 2014, 2018]

# Function to scrape World Cup match data for a given year
def get_matches(year):
    """
    This function scrapes match data (home team, score, away team) from Wikipedia for a specific World Cup year.
    
    Args:
    year (int): The World Cup year to scrape data from.

    Returns:
    pandas.DataFrame: A DataFrame containing scraped match data for the given year with an additional 'Year' column.
    """

    # Construct URL for the Wikipedia page of the specified year's FIFA World Cup
    url = f'https://en.wikipedia.org/wiki/{year}_FIFA_World_Cup'

    # Send an HTTP GET request to retrieve the webpage content
    response = requests.get(url)
    content = response.text

    # Parse the HTML content using BeautifulSoup
    soup = BeautifulSoup(content, 'lxml')

    # Find all elements containing match details
    matches = soup.find_all('div', class_='footballbox')

    # Initialize empty lists to store match details
    home = []
    score = []
    away = []

    # Loop through each match element and extract relevant details
    for match in matches:
        home.append(match.find('th', class_='fhome').get_text())
        score.append(match.find('th', class_='fscore').get_text())
        away.append(match.find('th', class_='faway').get_text())

    # Create a dictionary to store match details
    dict = {'Home' : home, 'Score' : score, 'Away' : away}

    # Create a DataFrame from the dictionary
    df_matches = pd.DataFrame(dict)

    # Add a column for the year of the FIFA World Cup
    df_matches['Year'] = year
    
    return df_matches

# Retrieve match data for each FIFA World Cup year using list comprehension
fifa = [get_matches(year) for year in years]

# Concatenate the DataFrames into a single DataFrame
df_fifa = pd.concat(fifa, ignore_index=True)

# Save the combined DataFrame to a CSV file
df_fifa.to_csv('all_fifa_worldcups_data.csv', index=False)

# %%
# Counting the occurrences of each year in the 'Year' column of df_fifa_data
df_fifa['Year'].value_counts().sort_index()

# %% [markdown]
# ## 2.1 Extracting FIFA 2022 fixtures

# %%
url = ("https://web.archive.org/web/20221115040351/https://en.wikipedia.org/wiki/2022_FIFA_World_Cup")
    
response = requests.get(url)
content = response.text
soup = BeautifulSoup(content, 'lxml')

# Find all elements containing fixture details
fixtures = soup.find_all('div', class_='footballbox')

# Using list comprehension to extract data from fixtures
home = [fixture.find('th', class_='fhome').get_text() for fixture in fixtures]
score = [fixture.find('th', class_='fscore').get_text() for fixture in fixtures]
away = [fixture.find('th', class_='faway').get_text() for fixture in fixtures]

# Creating a dictionary from the lists
fixture_dict = {'Home': home, 'Score': score, 'Away': away}

# Creating a DataFrame from the dictionary
df_fixtures = pd.DataFrame(fixture_dict)

# Adding the year column
df_fixtures['Year'] = 2022

# Exporting the DataFrame to a CSV file
df_fixtures.to_csv('fifa2022_fixtures.csv', index=False)

# %% [markdown]
# ## 2.2 Extracting missing data (1990)

# %%
from selenium import webdriver
from selenium.webdriver.common.by import By
import time

# Initialise Firefox WebDriver using the service
driver = webdriver.Firefox()
driver.maximize_window()

# List of Fifa World Cup years
years = [1930, 1934, 1938, 1950, 1954, 1958, 1962, 1966, 1970, 1974, 1978,
         1982, 1986, 1990, 1994, 1998, 2002, 2006, 2010, 2014, 2018]

def get_misssing_data(year):
    """
    This function retrieves match data (home team, score, away team) for a specific World Cup year 
    by scraping the Wikipedia page.

    Args:
    year (int): The World Cup year to scrape data from.

    Returns:
    pandas.DataFrame: A DataFrame containing scraped match data for the given year with an additional 'Year' column.
    """
    
    # Construct URL for the Wikipedia page of the specified year's FIFA World Cup
    url = f'https://en.wikipedia.org/wiki/{year}_FIFA_World_Cup'

    # Open the desired website
    driver.get(url)

    # Extracting data for each match from the table
    matches = driver.find_elements(By.CSS_SELECTOR, 'tr[style="font-size:90%"]')

    # Initialize empty lists to store match details
    home = []
    score = []
    away = []

    # Loop through each match element and extract relevant details
    for match in matches:
        home.append(match.find_element(By.CSS_SELECTOR, 'td[align="right"] a').text)
        score.append(match.find_element(By.CSS_SELECTOR, 'td[align="center"]').text)
        away.append(match.find_element(By.CSS_SELECTOR, 'td:nth-child(3) a').text)

    # Create a dictionary to store match details
    dict = {'Home': home, 'Score': score, 'Away': away}
    
    # Create a DataFrame from the dictionary
    df_matches = pd.DataFrame(dict)

    # Add a column for the year of the FIFA World Cup
    df_matches['Year'] = year

    # Pausing execution for 2 seconds to allow time for the webpage to load
    time.sleep(2)
    
    return df_matches

# Retrieve match data for each FIFA World Cup year using list comprehension
fifa = [get_misssing_data(year) for year in years]
# fifa = get_misssing_data(1990)

# Closing the WebDriver after scraping
driver.quit()

# Concatenate the DataFrames into a single DataFrame
df_fifa = pd.concat(fifa, ignore_index=True)

# Save the combined DataFrame to a CSV file
df_fifa.to_csv("fifa_worldcup_missing_data.csv", index=False)

# %% [markdown]
# # 3. Data cleaning and transformation

# %%
df_fifa_data = pd.read_csv('all_fifa_worldcups_data.csv')
df_fixture = pd.read_csv('fifa2022_fixtures.csv')
df_missing_data = pd.read_csv('fifa_worldcup_missing_data.csv')

# %% [markdown]
# ## 3.1 Cleaning fixtures and missing data

# %%
# Removing leading and trailing whitespace from the 'Home' and 'Away' columns
# Using apply() method to apply the strip() method to each element in the specified columns
df_fixture[['Home', 'Away']] = df_fixture[['Home', 'Away']].apply(lambda x: x.str.strip())
df_missing_data[['Home', 'Away']] = df_missing_data[['Home', 'Away']].apply(lambda x: x.str.strip())

# %%
df_fixture.isnull().sum()
# Out:
# Home     0
# Score    0
# Away     0
# Year     0
# dtype: int64

# %%
df_missing_data.isnull().sum()
# Out:
# Home     0
# Score    0
# Away     0
# Year     0
# dtype: int64

# %% [markdown]
# ## 3.2 Merging Fifa data and missing data

# %%
fifa_data_df = pd.concat([df_fifa_data, df_missing_data], ignore_index=True)
fifa_data_df.drop_duplicates(inplace=True)
fifa_data_df.sort_values('Year', inplace=True)
fifa_data_df
# Out:
#             Home Score            Away  Year
# 0        France    4–1          Mexico  1930
# 17      Uruguay    4–2       Argentina  1930
# 16      Uruguay    6–1      Yugoslavia  1930
# 15    Argentina    6–1   United States  1930
# 14     Paraguay    1–0         Belgium  1930
# ..           ...   ...             ...   ...
# 829      Serbia    0–2          Brazil  2018
# 828      Serbia    1–2     Switzerland  2018
# 827      Brazil    2–0      Costa Rica  2018
# 825  Costa Rica    0–1          Serbia  2018
# 812       Spain    2–2         Morocco  2018
#
# [901 rows x 4 columns]

# %% [markdown]
# ## 3.3 Cleaning merged data

# %%
# Iterating over each column to find and print the unique values
for column in fifa_data_df.columns:
    # Getting the unique values for the current column
    unique_values = fifa_data_df[column].unique()
    
    # Displaying the column name and its unique values
    display(f"Unique values in {column}: {unique_values}")
# Out:
# "Unique values in Home: ['France\\xa0' 'Uruguay\\xa0' 'Argentina\\xa0' 'Paraguay\\xa0'\n 'United States\\xa0' 'Romania\\xa0' 'Yugoslavia\\xa0' 'Chile\\xa0'\n 'Brazil\\xa0' 'Italy\\xa0' 'Germany\\xa0' 'Czechoslovakia\\xa0' 'Austria\\xa0'\n 'Sweden\\xa0' 'Switzerland\\xa0' 'Hungary\\xa0' 'Spain\\xa0' 'Cuba\\xa0'\n 'England\\xa0' 'West Germany\\xa0' 'Turkey\\xa0' 'Soviet Union\\xa0'\n 'Wales\\xa0' 'Northern Ireland\\xa0' 'Mexico\\xa0' 'North Korea\\xa0'\n 'Portugal\\xa0' 'Bulgaria\\xa0' 'Peru\\xa0' 'Belgium\\xa0' 'Poland\\xa0'\n 'Netherlands\\xa0' 'East Germany\\xa0' 'Haiti\\xa0' 'Australia\\xa0'\n 'Zaire\\xa0' 'Scotland\\xa0' 'Tunisia\\xa0' 'Honduras\\xa0' 'Algeria\\xa0'\n 'Denmark\\xa0' 'Morocco\\xa0' 'South Korea\\xa0' 'Iraq\\xa0' 'Canada\\xa0'\n 'Cameroon' 'Costa Rica' 'Brazil' 'Argentina' 'Austria' 'Italy'\n 'United States' 'Sweden' 'Soviet Union' 'South Korea'\n 'United Arab Emirates' 'Republic of Ireland' 'England' 'Netherlands'\n 'Belgium' 'Uruguay' 'Yugoslavia' 'West Germany' 'Cameroon\\xa0'\n 'Republic of Ireland\\xa0' 'Bolivia\\xa0' 'Russia\\xa0' 'Colombia\\xa0'\n 'Nigeria\\xa0' 'Saudi Arabia\\xa0' 'Greece\\xa0' 'Norway\\xa0'\n 'South Africa\\xa0' 'FR Yugoslavia\\xa0' 'Japan\\xa0' 'Jamaica\\xa0'\n 'Senegal\\xa0' 'Costa Rica\\xa0' 'China\\xa0' 'Slovenia\\xa0' 'Ecuador\\xa0'\n 'Croatia\\xa0' 'Ukraine\\xa0' 'Angola\\xa0' 'Ivory Coast\\xa0'\n 'Serbia and Montenegro\\xa0' 'Trinidad and Tobago\\xa0' 'Iran\\xa0'\n 'Togo\\xa0' 'Czech Republic\\xa0' 'Ghana\\xa0' 'New Zealand\\xa0'\n 'Slovakia\\xa0' 'Serbia\\xa0' 'Bosnia and Herzegovina\\xa0' 'Egypt\\xa0'\n 'Iceland\\xa0' 'Panama\\xa0']"
# "Unique values in Score: ['4–1' '4–2' '6–1' '1–0' '3–0' '4–0' '3–1' '2–1' '6–3' '1–1 (a.e.t.)'\n '2–1 (a.e.t.)' '3–2' '3–2 (a.e.t.)' '7–1' '5–2' '8–0' '5–1' '2–0'\n '3–0 (a.e.t.)' '6–5 (a.e.t.)' '3–3 (a.e.t.)' 'w/o' '6–0' '2–2' '7–5'\n '4–2 (a.e.t.)' '4–4 (a.e.t.)' '7–0' '5–0' '8–3' '7–2' '9–0' '0–0' '1–3'\n '7–3' '3–3' '1–1' '4–4' '5–3' '0–1 (a.e.t.)' '4–3 (a.e.t.)' '0–1' '1–2'\n '0–2' '0–7' '0–3' '1–4' '1–5' '3–1 (a.e.t.)' '10–1' '3–4 (a.e.t.)'\n '0–0 (a.e.t.)' '2–4 (a.e.t.)' '2–3' '0–4' '2–3 (a.e.t.)' '1–0 (a.e.t.)'\n '1–2 (a.e.t.)' '2–2 (a.e.t.)' '1–0 (a.e.t./g.g.)' '2–1 (a.e.t./g.g.)'\n '1–2 (a.e.t./g.g.)' '0–1 (a.e.t./g.g.)' '2–5' '0–2 (a.e.t.)' '1–7' '2–4'\n '4–3']"
# "Unique values in Away: ['\\xa0Mexico' '\\xa0Argentina' ' Yugoslavia' '\\xa0United States'\n '\\xa0Belgium' '\\xa0Paraguay' '\\xa0Romania' '\\xa0Peru' '\\xa0Bolivia'\n '\\xa0Brazil' '\\xa0Chile' '\\xa0France' '\\xa0Spain' '\\xa0Czechoslovakia'\n '\\xa0Austria' '\\xa0\\xa0Switzerland' '\\xa0Sweden' '\\xa0Hungary'\n '\\xa0Germany' '\\xa0Netherlands' '\\xa0Egypt' '\\xa0Cuba' '\\xa0Poland'\n '\\xa0Norway' '\\xa0Dutch East Indies' '\\xa0Italy' '\\xa0England'\n '\\xa0Yugoslavia' '\\xa0Uruguay' '\\xa0Scotland' '\\xa0Turkey'\n '\\xa0West Germany' '\\xa0South Korea' '\\xa0Soviet Union'\n '\\xa0Northern Ireland' '\\xa0Wales' '\\xa0Bulgaria' '\\xa0Colombia'\n '\\xa0North Korea' '\\xa0Portugal' '\\xa0Morocco' '\\xa0El Salvador'\n '\\xa0Israel' '\\xa0East Germany' '\\xa0Haiti' '\\xa0Australia' '\\xa0Zaire'\n '\\xa0Iran' '\\xa0Tunisia' '\\xa0New Zealand' '\\xa0Kuwait' '\\xa0Honduras'\n '\\xa0Cameroon' '\\xa0Algeria' '\\xa0Denmark' '\\xa0Iraq' '\\xa0Canada'\n 'Romania' 'Scotland' 'Sweden' 'Soviet Union' 'Costa Rica'\n 'Czechoslovakia' 'Cameroon' 'United States' 'Uruguay' 'Colombia'\n 'Austria' 'Egypt' 'Netherlands' 'Republic of Ireland' 'Spain'\n 'South Korea' 'United Arab Emirates' 'Yugoslavia' '\\xa0Costa Rica'\n '\\xa0Nigeria' '\\xa0Russia' '\\xa0Greece' '\\xa0Republic of Ireland'\n '\\xa0Saudi Arabia' '\\xa0Croatia' '\\xa0FR Yugoslavia' '\\xa0South Africa'\n '\\xa0Jamaica' '\\xa0Japan' '\\xa0Senegal' '\\xa0China' '\\xa0Ecuador'\n '\\xa0Slovenia' '\\xa0Ukraine' '\\xa0Ghana' '\\xa0Angola'\n '\\xa0Serbia and Montenegro' '\\xa0Ivory Coast' '\\xa0Trinidad and Tobago'\n '\\xa0Czech Republic' '\\xa0Togo' '\\xa0Slovakia' '\\xa0Serbia'\n '\\xa0Bosnia and Herzegovina' '\\xa0Iceland' '\\xa0Panama']"
# 'Unique values in Year: [1930 1934 1938 1950 1954 1958 1962 1966 1970 1974 1978 1982 1986 1990\n 1994 1998 2002 2006 2010 2014 2018]'

# %%
# Removing leading and trailing whitespace from the 'Home' and 'Away' columns
fifa_data_df[['Home', 'Away']] = fifa_data_df[['Home', 'Away']].apply(lambda x: x.str.strip())

# %%
# Filtering "fifa_data_df" to find rows where the value in the "Score" column is 'w/o'
rows_with_wo = fifa_data_df[fifa_data_df['Score'] == 'w/o']
rows_with_wo
# Out:
#       Home Score     Away  Year
# 37  Sweden   w/o  Austria  1938

# %% [markdown]
# Sweden were awarded a walkover as Austria were unable to compete because of the Austrian Anschluss in March 1938.

# %%
# Finding the index of "rows_with_wo"
row_to_drop = rows_with_wo.index

# Dropping the rows with the identified indices
fifa_data_df.drop(row_to_drop, inplace=True)

# %%
# Replacing parentheses and their contents with an empty string
# fifa_data_df['Score'] = fifa_data_df['Score'].str.replace(r'\(.*?\)', '', regex=True)

# %%
# Checking if the 'Score' column contains any characters other than digits and the dash symbol '–'
fifa_data_df['Score'] = fifa_data_df['Score'].str.replace('[^\d–]', '', regex=True)

# %%
# Stripping leading and trailing whitespaces
fifa_data_df['Score'] = fifa_data_df['Score'].str.strip()

# %%
fifa_data_df[['HomeGoals', 'AwayGoals']] = fifa_data_df['Score'].str.split('–', expand=True)
fifa_data_df
# Out:
#            Home Score           Away  Year HomeGoals AwayGoals
# 0        France   4–1         Mexico  1930         4         1
# 17      Uruguay   4–2      Argentina  1930         4         2
# 16      Uruguay   6–1     Yugoslavia  1930         6         1
# 15    Argentina   6–1  United States  1930         6         1
# 14     Paraguay   1–0        Belgium  1930         1         0
# ..          ...   ...            ...   ...       ...       ...
# 829      Serbia   0–2         Brazil  2018         0         2
# 828      Serbia   1–2    Switzerland  2018         1         2
# 827      Brazil   2–0     Costa Rica  2018         2         0
# 825  Costa Rica   0–1         Serbia  2018         0         1
# 812       Spain   2–2        Morocco  2018         2         2
#
# [900 rows x 6 columns]

# %%
# Deleting the 'Score' column from the DataFrame
fifa_data_df.drop('Score', axis=1, inplace=True)

# %%
# Renaming columns
fifa_data_df.rename(columns={'Home' : 'HomeTeam', 'Away' : 'AwayTeam'}, inplace=True)

# Converting columns to integer type
fifa_data_df = fifa_data_df.astype({'HomeGoals' : int, 'AwayGoals' : int})

# Creating new column "TotalGoals"
fifa_data_df['TotalGoals'] = fifa_data_df['HomeGoals'] + fifa_data_df['AwayGoals']

# %% [markdown]
# ## 3.4 Exporting cleaned data

# %%
fifa_data_df.to_csv('cleaned_all_fifa_worldcups_data', index=False)
df_fixture.to_csv('cleaned_fifa2022_fixtures.csv', index=False)

# %% [markdown]
# ## 3.5 Verification

# %%
# Counting the occurrences of each year in the 'Year' column of df_
fifa_data_df['Year'].value_counts().sort_index()
# Out:
# Year
# 1930    18
# 1934    17
# 1938    18
# 1950    22
# 1954    26
# 1958    35
# 1962    32
# 1966    32
# 1970    32
# 1974    38
# 1978    38
# 1982    52
# 1986    52
# 1990    52
# 1994    52
# 1998    64
# 2002    64
# 2006    64
# 2010    64
# 2014    64
# 2018    64
# Name: count, dtype: int64

# %% [markdown]
# # 4. Prediction

# %%
from scipy.stats import poisson

# %%
fifa2022_grpTab = pickle.load(open('fifa2022_group_table','rb'))

# %% [markdown]
# ## 4.1 Calculating Team Strength

# %%
# Extracting relevant columns for home and away teams
df_home = fifa_data_df[['HomeTeam', 'HomeGoals', 'AwayGoals']]
df_away = fifa_data_df[['AwayTeam', 'HomeGoals', 'AwayGoals']]

# Renaming columns for home and away teams
df_home = df_home.rename(columns={'HomeTeam': 'Team', 'HomeGoals': 'GoalsFor', 'AwayGoals': 'GoalsAgainst'})
df_away = df_away.rename(columns={'AwayTeam': 'Team', 'HomeGoals': 'GoalsAgainst', 'AwayGoals': 'GoalsFor'})

# Concatenating home and away team dataFrames and calculating mean 'goals for and against' for each team
df_team_strength = pd.concat([df_home, df_away], ignore_index=True).groupby(['Team']).mean()
df_team_strength
# Out:
#               GoalsFor  GoalsAgainst
# Team
# Algeria       1.000000      1.461538
# Angola        0.333333      0.666667
# Argentina     1.691358      1.148148
# Australia     0.812500      1.937500
# Austria       1.482759      1.620690
# ...                ...           ...
# Uruguay       1.553571      1.321429
# Wales         0.800000      0.800000
# West Germany  2.112903      1.241935
# Yugoslavia    1.666667      1.272727
# Zaire         0.000000      4.666667
#
# [85 rows x 2 columns]

# %% [markdown]
# ## 4.2 Function to predict match points

# %%
def predict_points(home, away):
    """
    Predicts points for home and away teams based on Poisson distribution

    Args:
    home (str): Name of the home team
    away (str): Name of the away team

    Returns:
      tuple: Tuple containing predicted points for home and away teams (float, float)
          - The first element is the predicted points for the home team.
          - The second element is the predicted points for the away team.
          - If either team is not found in the team strength data, returns (0, 0).
    """
    
    # Checking if both teams are present in the team strength DataFrame
    if home in df_team_strength.index and away in df_team_strength.index:
        # Calculating lambda values for Poisson distribution based on team strengths (attack and defence strengths)
        lamb_home = df_team_strength.at[home,'GoalsFor'] * df_team_strength.at[away,'GoalsAgainst']
        lamb_away = df_team_strength.at[away,'GoalsFor'] * df_team_strength.at[home,'GoalsAgainst']
        
        # Initialising probabilities for home win, away win, and draw (all set to 0 initially)
        prob_home, prob_away, prob_draw = 0, 0, 0
        
        # Looping through possible number of goals scored by home and away teams (0 to 10 goals each)
        for x in range(0,11): #number of goals home team
            for y in range(0, 11): #number of goals away team
                # Calculating the probability of the current goal combination using Poisson distribution
                p = poisson.pmf(x, lamb_home) * poisson.pmf(y, lamb_away)
                
                # Determining the outcome (home win, away win, or draw) based on the goal combination
                if x == y:
                    prob_draw += p # Add probability to draw
                elif x > y:
                    prob_home += p # Add probability to home win
                else:
                    prob_away += p # Add probability to away win

        # Calculating points based on win (3 points) and draw (1 point)
        points_home = 3 * prob_home + prob_draw
        points_away = 3 * prob_away + prob_draw
        
        # Return the predicted points for home and away teams
        return (home, points_home), (away, points_away)
    else:
        # Return 0 points for both teams if either home or away team is not present in the team strength DataFrame
        return (home, 0), (away, 0)

# %%
# Testing function
print(predict_points('England', 'United States'))
print(predict_points('Nigeria', 'Ghana'))

# Qatar (H) made her debut in the FIFA World Cup in 2022
print(predict_points('Qatar (H)', 'Ecuador'))
# Out:
# (('England', 2.2356147635326007), ('United States', 0.5922397535606193))
# (('Nigeria', 1.321294620797116), ('Ghana', 1.4363162056734256))
# (('Qatar (H)', 0), ('Ecuador', 0))

# %% [markdown]
# Based on the prediction model, if England plays the United States:
# * England has a higher chance of winning and is predicted to earn around 2.23 points out of a possible 3.
# * The United States is predicted to get fewer points (around 0.59), reflecting a lower chance of winning.
#
# In football, a win typically awards 3 points, so these predictions suggest England is more likely to win and get the full 3 points, while the United States is less likely to win and might get a point for a draw.

# %% [markdown]
# # 5. Predicting the World Cup

# %% [markdown]
# ## 5.1 Group stage

# %%
# Splitting fixtures into group stage, knockout, quarter, semi and final
df_fixture_group_48 = df_fixture[:48].copy()
df_fixture_knockout = df_fixture[48:56].copy()
df_fixture_quarter = df_fixture[56:60].copy()
df_fixture_semi = df_fixture[60:62].copy()
df_fixture_final = df_fixture[62:].copy()

# %%
# Looping through each group in the dictionary
for group in dict_table:
    # Getting the list of teams in the current group
    teams_in_group = dict_table[group]['Team'].values
    
    # Filtering the fixture DataFrame to include only matches involving teams in the current group
    df_fixture_group_6 = df_fixture_group_48[df_fixture_group_48['Home'].isin(teams_in_group)]
    
    # Looping through each fixture in the filtered fixture DataFrame
    for index, row in df_fixture_group_6.iterrows():
        # Getting the home and away teams for the current fixture
        home, away = row['Home'], row['Away']
        
        # Predicting points for the home and away teams in the fixture
        points_home, points_away = predict_points(home, away)
        
        # Updating the points for the home and away teams in the group DataFrame
        dict_table[group].loc[dict_table[group]['Team'] == home, 'Pts'] += int(points_home[1])
        dict_table[group].loc[dict_table[group]['Team'] == away, 'Pts'] += int(points_away[1])

    # Sorting the teams in the group DataFrame based on points in descending order
    dict_table[group] = dict_table[group].sort_values('Pts', ascending=False).reset_index()
    
    # Retaining only the 'Team' and 'Pts' columns in the group DataFrame
    dict_table[group] = dict_table[group][['Team', 'Pts']]
    
    # Rounding off the points to the nearest integer
    
    dict_table[group] = dict_table[group].round(0)

# %%
dict_table['Group A']
# Out:
#           Team  Pts
# 0  Netherlands   10
# 1      Ecuador    5
# 2      Senegal    5
# 3    Qatar (H)    0

# %% [markdown]
# ## 5.2 Knockout stage

# %%
df_fixture_knockout
# Out:
#                Home     Score                Away  Year
# 48  Winners Group A  Match 49  Runners-up Group B  2022
# 49  Winners Group C  Match 50  Runners-up Group D  2022
# 50  Winners Group D  Match 52  Runners-up Group C  2022
# 51  Winners Group B  Match 51  Runners-up Group A  2022
# 52  Winners Group E  Match 53  Runners-up Group F  2022
# 53  Winners Group G  Match 54  Runners-up Group H  2022
# 54  Winners Group F  Match 55  Runners-up Group E  2022
# 55  Winners Group H  Match 56  Runners-up Group G  2022

# %%
# Iterating through each group in the dictionary
for group in dict_table:
    # Getting the winner and runner-up of the current group
    group_winner = dict_table[group].loc[0, 'Team']
    runners_up = dict_table[group].loc[1, 'Team']
    
    # Replacing placeholders in the knockout fixture DataFrame with actual group winners and runners-up
    df_fixture_knockout.replace({f'Winners {group}': group_winner, f'Runners-up {group}': runners_up}, inplace=True)

# Adding a column named 'Winner' initialised with placeholder '?' to the knockout fixture DataFrame
df_fixture_knockout['Winner'] = '?'

# Displaying the updated knockout fixture DataFrame
df_fixture_knockout
# Out:
#            Home     Score         Away  Year Winner
# 48  Netherlands  Match 49        Wales  2022      ?
# 49    Argentina  Match 50      Denmark  2022      ?
# 50       France  Match 52       Poland  2022      ?
# 51      England  Match 51      Ecuador  2022      ?
# 52      Germany  Match 53      Belgium  2022      ?
# 53       Brazil  Match 54      Uruguay  2022      ?
# 54      Croatia  Match 55        Spain  2022      ?
# 55     Portugal  Match 56  Switzerland  2022      ?

# %%
# Function to determine the winner of each fixture based on predicted points
def get_winner(df_fixture_updated):
    # Looking through each fixture in the updated fixture DataFrame
    for index, row in df_fixture_updated.iterrows():
        # Getting the home and away teams for the current fixture
        home, away = row['Home'], row['Away']
        
        # Predicting points for the home and away teams in the fixture
        points_home, points_away = predict_points(home, away)
        
        # Determining the winner based on points scored by each team
        if points_home > points_away:
            Winner = home
        else:
            Winner = away
        
        # Assigning the winner to the 'winner' column in the fixture DataFrame
        df_fixture_updated.loc[index, 'Winner'] = Winner
    
    # Returning the updated fixture DataFrame with the winner information
    return df_fixture_updated

# %%
get_winner(df_fixture_knockout)
# Out:
#            Home     Score         Away  Year       Winner
# 48  Netherlands  Match 49        Wales  2022        Wales
# 49    Argentina  Match 50      Denmark  2022      Denmark
# 50       France  Match 52       Poland  2022       Poland
# 51      England  Match 51      Ecuador  2022      England
# 52      Germany  Match 53      Belgium  2022      Germany
# 53       Brazil  Match 54      Uruguay  2022      Uruguay
# 54      Croatia  Match 55        Spain  2022        Spain
# 55     Portugal  Match 56  Switzerland  2022  Switzerland

# %% [markdown]
# ## 5.3 Quarter final

# %%
# Function to update the knockout table for the next round based on the results of the current round
def update_table(df_fixture_round_1, df_fixture_round_2):
    # Looping through each fixture in the first round DataFrame
    for index, row in df_fixture_round_1.iterrows():
        # Getting the winner and match identifier for the current fixture
        winner = df_fixture_round_1.loc[index, 'Winner']
        match = df_fixture_round_1.loc[index, 'Score']
        
        # Replacing placeholders in the second round fixture DataFrame with the winner of the current match
        df_fixture_round_2.replace({f'Winners {match}': winner}, inplace=True)
    
    # Adding a column named 'winner' initialized with placeholder '?' to the second round fixture DataFrame
    df_fixture_round_2['Winner'] = '?'
    
    # Returning the updated second round fixture DataFrame
    return df_fixture_round_2

# %%
update_table(df_fixture_knockout, df_fixture_quarter)
# Out:
#        Home     Score         Away  Year Winner
# 56  Germany  Match 58      Uruguay  2022      ?
# 57    Wales  Match 57      Denmark  2022      ?
# 58    Spain  Match 60  Switzerland  2022      ?
# 59  England  Match 59       Poland  2022      ?

# %%
get_winner(df_fixture_quarter)
# Out:
#        Home     Score         Away  Year       Winner
# 56  Germany  Match 58      Uruguay  2022      Uruguay
# 57    Wales  Match 57      Denmark  2022        Wales
# 58    Spain  Match 60  Switzerland  2022  Switzerland
# 59  England  Match 59       Poland  2022       Poland

# %% [markdown]
# ## 5.4 Semi final

# %%
update_table(df_fixture_quarter, df_fixture_semi)
# Out:
#       Home     Score         Away  Year Winner
# 60   Wales  Match 61      Uruguay  2022      ?
# 61  Poland  Match 62  Switzerland  2022      ?

# %%
get_winner(df_fixture_semi)
# Out:
#       Home     Score         Away  Year       Winner
# 60   Wales  Match 61      Uruguay  2022        Wales
# 61  Poland  Match 62  Switzerland  2022  Switzerland

# %% [markdown]
# ## 5.5 Final

# %%
update_table(df_fixture_semi, df_fixture_final)
# Out:
#                Home     Score             Away  Year Winner
# 62  Losers Match 61  Match 63  Losers Match 62  2022      ?
# 63            Wales  Match 64      Switzerland  2022      ?

# %%
get_winner(df_fixture_final)
# Out:
#                Home     Score             Away  Year           Winner
# 62  Losers Match 61  Match 63  Losers Match 62  2022  Losers Match 62
# 63            Wales  Match 64      Switzerland  2022            Wales
